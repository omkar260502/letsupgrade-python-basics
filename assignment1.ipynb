# %%
"""Question 1
Write the definition of tuple with a proper example."""
#Answer-
print("Tuples are used to store multiple items in a single variable.\nA tuple is a collection which is ordered and unchangeable.")
#Example
Tuple=("Omkar","Shashikant","Taple")
print(Tuple)
# Out:
# Tuples are used to store multiple items in a single variable.
# A tuple is a collection which is ordered and unchangeable.
# ('Omkar', 'Shashikant', 'Taple')

# %%
"""Question 2
Write the code for implementing sub dictionary inside dictionary"""
#Answer-
Dict={1:"let's upgrade" ,2:"CR7" ,3:{"a":"Omkar","b":"Shashikant","c":"Taple"}}
print(Dict)
# Out:
# {1: "let's upgrade", 2: 'CR7', 3: {'a': 'Omkar', 'b': 'Shashikant', 'c': 'Taple'}}

# %%
print(Dict.keys())
# Out:
# dict_keys([1, 2, 3])

# %%
print(Dict.values())
# Out:
# dict_values(["let's upgrade", 'CR7', {'a': 'Omkar', 'b': 'Shashikant', 'c': 'Taple'}])

# %%
print (Dict[3])
# Out:
# {'a': 'Omkar', 'b': 'Shashikant', 'c': 'Taple'}

# %%
print(len(Dict))
# Out:
# 3

# %%
print(Dict[3]['a'])
# Out:
# Omkar

# %%
print(Dict.get(2))
# Out:
# CR7

# %%
Dict[5]='Pune'

# %%
print(Dict)
# Out:
# {1: "let's upgrade", 2: 'CR7', 3: {'a': 'Omkar', 'b': 'Shashikant', 'c': 'Taple'}, 5: 'Pune'}

# %%
print(Dict.pop(2))
# Out:
# CR7
